# %% [markdown]
# # Python SWC workshop Sept. 2026
#
# Sarah Stueve

# %%
age = 29
first_name = "Sarah"

# %%
print(first_name, "is", age, "years old")
print('hello world!')
# Out:
# Sarah is 29 years old
# hello world!

# %%
last_name = 'Stueve'
print(last_name)
# Out:
# Stueve

# %%
print('hello world', '!')
print('hello world' + '!')
# Out:
# hello world !
# hello world!

# %%
age_in_3 = age + 3
print(first_name, "will be", age_in_3, "in three years.")
# Out:
# Sarah will be 32 in three years.

# %%
first_name
# Out:
# 'Sarah'

# %%
first_name[0]
# Out:
# 'S'

# %%
first_name[0:3]
# Out:
# 'Sar'

# %%
print(len('helium'))
# Out:
# 6

# %%
First_Name
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 First_Name
#
# NameError: name 'First_Name' is not defined

# %%
x = 'Sarah'
y = 'teacher'

# %%
flabadab = 42
ewr_422_yY = 'Ahmed'
print(flabadab, 'is', ewr_422_yY, 'years old')
# Out:
# 42 is Ahmed years old

# %%
x = 1.0
y = 3.0

# %%
print(x)
print(y)
# Out:
# 1.0
# 3.0

# %%
swap = x
print(swap)
# Out:
# 1.0

# %%
x = y
print(swap)
# Out:
# 1.0

# %%
print(type(52))
# Out:
# <class 'int'>

# %%
fitness = 'average'
print(type(fitness))
# Out:
# <class 'str'>

# %%
print(5 - 3)
# Out:
# 2

# %%
print('hello' - 'h')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 print('hello' - 'h')
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
'hello'[1:]
# Out:
# 'ello'

# %%
full_name = 'Sarah' + ' ' + 'Stueve'
print(full_name)
# Out:
# Sarah Stueve

# %%
separator = "=" * 10
print(separator)
# Out:
# ==========

# %%
full_name * 10
# Out:
# 'Sarah StueveSarah StueveSarah StueveSarah StueveSarah StueveSarah StueveSarah StueveSarah StueveSarah StueveSarah Stueve'

# %%
len(full_name)
# Out:
# 12

# %%
len(11)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 len(11)
#
# TypeError: object of type 'int' has no len()

# %%
print(1 + '2')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 print(1 + '2')
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
print('1' + '2')
# Out:
# 12

# %%
print(str(1) + '2')
# Out:
# 12

# %%
print('half is', 1 / 2.0)
# Out:
# half is 0.5

# %%
print('three squared is', 3 ** 2)
# Out:
# three squared is 9

# %%
float(3)
# Out:
# 3.0

# %%
int(3.1459)
# Out:
# 3

# %%
int(3.678)
# Out:
# 3

# %%
round(3.678)
# Out:
# 4

# %%
round(3.678, 1)
# Out:
# 3.7

# %%
variable_1 = 1
variable_1 = 2
variable_2 = 5 * variable_1
print(variable_1, variable_2)
# Out:
# 2 10

# %%
print
# Out:
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>

# %%
my_string = 'Hello World!'
print(len(my_string))
print(my_string.swapcase())
# Out:
# 12
# hELLO wORLD!
